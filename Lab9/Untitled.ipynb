# %%
import numpy as np
import pandas as pd

# %%
data = [pd.read_csv('regions_pl_uro_{}_00_2p.csv'.format(year)) for year in range(2002, 2017)]

# %%
data[0]
# Out:
#     Unnamed: 0                          region    total        1        2  \
# 0            4   DOLNOŚLĄSKIE                   24588.0  12684.0   7543.0
# 1           41   KUJAWSKO-POMORSKIE             20238.0  10074.0   6132.0
# 2           71   LUBELSKIE                      20908.0   9548.0   6437.0
# 3          102   LUBUSKIE                        9486.0   4730.0   2926.0
# 4          123   ŁÓDZKIE                        22258.0  11419.0   7113.0
# 5          154   MAŁOPOLSKIE                    32451.0  14710.0  10254.0
# 6          183   MAZOWIECKIE                    46627.0  23028.0  14821.0
# 7          232   OPOLSKIE                        8506.0   3938.0   2704.0
# 8          251   PODKARPACKIE                   21414.0   9488.0   6592.0
# 9          283   PODLASKIE                      11318.0   5032.0   3526.0
# 10         307   POMORSKIE                      22402.0  10758.0   6794.0
# 11         334   ŚLĄSKIE                        39557.0  20291.0  12363.0
# ...
